# %% [markdown]
# <a href="https://colab.research.google.com/github/rekuantsun/PTDL-Python/blob/main/Numpy_5_Tensor.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# BÀI TẬP 1

# %%
import PIL as pt 
import numpy as np

# %%
from google.colab import drive
drive.mount('/content/drive')
doc_img = pt.Image.open("/content/drive/MyDrive/hinh-troi-dep-anime-820x461.jpg")
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %%
doc_img
# Out:
# <PIL.JpegImagePlugin.JpegImageFile image mode=RGB size=820x461 at 0x7FBA02B86910>

# %%
#Chuyển bức ảnh từ cấu trúc dữ liệu của PIL sang NumPy array 
change_img = np.array(doc_img.getdata())

# %%
#Số chiều
change_img.ndim
# Out:
# 2

# %%
#kkích thước
change_img.shape
# Out:
# (378020, 3)

# %%
change_img
# Out:
# array([[ 18,  94, 169],
#        [ 18,  94, 169],
#        [ 18,  94, 169],
#        ...,
#        [ 97, 209, 229],
#        [ 94, 206, 226],
#        [ 93, 205, 225]])

# %%
#chuyển ảnh màu sang ảnh xám 
new_img = doc_img.convert("L")
new_img
# Out:
# <PIL.Image.Image image mode=L size=820x461 at 0x7FBA08A25610>

# %%
#lưu vào máy
new_img.save("new_totoro.jpg")

# %%
#phóng to ảnh
new_width  = 600
new_height = 600
big_img = doc_img.resize((new_width,new_height))
big_img
# Out:
# <PIL.Image.Image image mode=RGB size=600x600 at 0x7FBA02B0E3D0>

# %%
#thu nhỏ ảnh
new_height_ = 200
new_width_  = 200
small_img = doc_img.resize((new_height_,new_width_))
small_img
# Out:
# <PIL.Image.Image image mode=RGB size=200x200 at 0x7FB9FFD9B150>

# %%
#Chuyển ảnh màu sang Halftone 
new_img = doc_img.convert("1")
new_img
# Out:
# <PIL.Image.Image image mode=1 size=820x461 at 0x7FBA15973C90>

# %%
#làm mờ ảnh 
from PIL import ImageFilter
new_img = doc_img.filter(ImageFilter.GaussianBlur(radius=20))
new_img
# Out:
# <PIL.Image.Image image mode=RGB size=820x461 at 0x7FBA02B1C890>

# %%
#xoay ảnh 
n_img = doc_img.rotate((180))
n_img
# Out:
# <PIL.Image.Image image mode=RGB size=820x461 at 0x7FBA02B0EF90>

# %% [markdown]
# Bài tập 2 - Thư viện thao tác với cấu trúc Tensor

# %%
#PyTorch 
import torch

# %%
#Tensor hạng 1 
ts_1 = torch.tensor([1,2,3,4,5])
print("Tensor hạng 1: ",ts_1)
print("hạng: ",ts_1.ndim)
# Out:
# Tensor hạng 1:  tensor([1, 2, 3, 4, 5])
# hạng:  1

# %%
#Tensor hạng 2
ts_2 = torch.rand(2,2)
print("Tensor hạng 2: ")
print(ts_2)
print("hạng : ",ts_2.ndim)
# Out:
# Tensor hạng 2:
# tensor([[0.0247, 0.6996],
#         [0.5250, 0.0404]])
# hạng :  2

# %%
#Tensor hạng 3
ts_3 = torch.rand(2,3,5)
print("Tensor hạng 3: ")
print(ts_3)
print("hạng : ",ts_3.ndim)
# Out:
# Tensor hạng 3:
# tensor([[[0.2803, 0.6914, 0.8786, 0.8967, 0.7392],
#          [0.7647, 0.5918, 0.1850, 0.8726, 0.6346],
#          [0.3996, 0.8685, 0.8801, 0.7207, 0.4881]],
#
#         [[0.5690, 0.6820, 0.9341, 0.7855, 0.3125],
#          [0.9989, 0.9577, 0.3536, 0.2092, 0.8488],
#          [0.7334, 0.4555, 0.7206, 0.5639, 0.2822]]])
# hạng :  3

# %%
#Tensor hạng 4
ts_4 = torch.rand(1,3,4,6)
print("Tensor hạng 4: ")
print(ts_4)
print("hạng : ",ts_4.ndim)
# Out:
# Tensor hạng 4:
# tensor([[[[0.8342, 0.9529, 0.4568, 0.4060, 0.6878, 0.3503],
#           [0.4158, 0.1312, 0.6459, 0.7176, 0.8114, 0.1484],
#           [0.8725, 0.9934, 0.5918, 0.0296, 0.7539, 0.5207],
#           [0.4549, 0.0855, 0.6189, 0.4341, 0.8545, 0.3178]],
#
#          [[0.4189, 0.5312, 0.1594, 0.4948, 0.2668, 0.5704],
#           [0.6744, 0.8614, 0.9960, 0.1865, 0.6215, 0.4986],
#           [0.2016, 0.5898, 0.5123, 0.3524, 0.2601, 0.4255],
#           [0.0634, 0.3041, 0.5170, 0.3551, 0.1151, 0.5634]],
#
#          [[0.1090, 0.5609, 0.5254, 0.9348, 0.5623, 0.3530],
#           [0.7742, 0.0193, 0.6372, 0.7255, 0.8515, 0.8452],
#           [0.8818, 0.8116, 0.1049, 0.0722, 0.3207, 0.2555],
#           [0.6386, 0.2148, 0.0933, 0.5310, 0.7597, 0.5382]]]])
# hạng :  4
