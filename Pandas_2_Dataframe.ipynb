# %% [markdown]
# <a href="https://colab.research.google.com/github/rekuantsun/PTDL-Python/blob/main/Pandas_2_Dataframe.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ho_va_ten = pd.Series(["Lê Quang Trung","Trần Công Huy","Nguyễn Đình Thịnh","Nguyễn Đắc Nhẫn Minh","Đặng Thái Nhật Minh ","Lê Tuấn Anh","Phạm Thị Lê Na","Lê Quang Hòa","Hồ Thị Tuyết","Nguyễn Thanh Triều"])
ngay_sinh = pd.Series(["29/11/2002","18/1/2002","22/07/2002","16/05/2002","22/02/2002","30/10/2002","25/04/2003","1/9/1975","10/5/1982","9/3/2001"])
tien_cong_gio  = pd.Series([100,4000,6000,300,8000,70,300,20,500,9000])
so_gio_cong = pd.Series([1,2,4,6,8,7,9,3,10,4])
thuc_linh = pd.Series([])
# Out:
# /usr/local/lib/python3.7/dist-packages/ipykernel_launcher.py:5: DeprecationWarning: The default dtype for empty Series will be 'object' instead of 'float64' in a future version. Specify a dtype explicitly to silence this warning.
#   """

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df = pd.DataFrame({"Họ và tên":ho_va_ten,"Ngày sinh":ngay_sinh,"Tiền công/giờ":tien_cong_gio,"Số giờ công": so_gio_cong,"Thực lĩnh":thuc_linh})
df["Thực lĩnh"]= df["Số giờ công"]* df["Tiền công/giờ"]
df
# Out:
#               Họ và tên   Ngày sinh  Tiền công/giờ  Số giờ công  Thực lĩnh
# 0        Lê Quang Trung  29/11/2002            100            1        100
# 1         Trần Công Huy   18/1/2002           4000            2       8000
# 2     Nguyễn Đình Thịnh  22/07/2002           6000            4      24000
# 3  Nguyễn Đắc Nhẫn Minh  16/05/2002            300            6       1800
# 4  Đặng Thái Nhật Minh   22/02/2002           8000            8      64000
# 5           Lê Tuấn Anh  30/10/2002             70            7        490
# 6        Phạm Thị Lê Na  25/04/2003            300            9       2700
# 7          Lê Quang Hòa    1/9/1975             20            3         60
# 8          Hồ Thị Tuyết   10/5/1982            500           10       5000
# 9    Nguyễn Thanh Triều    9/3/2001           9000            4      36000

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ho_va_ten = pd.Series(["Lê Quang Trung","Trần Công Huy","Nguyễn Đình Thịnh","Nguyễn Đắc Nhẫn Minh","Đặng Thái Nhật Minh ","Lê Tuấn Anh","Phạm Thị Lê Na","Lê Quang Hòa","Hồ Thị Tuyết","Nguyễn Thanh Triều"])
tuoi = [19,20,19,19,20,19,18,46,39,21]
gioi_tinh = ["nam","nam","nam","nam","nam","nam","nữ","nam","nữ","nam"]
df1 = pd.DataFrame(np.array([ho_va_ten,tuoi,gioi_tinh]).T,columns =["Họ và tên","Tuổi","Giới tính"])
df1
# Out:
#               Họ và tên Tuổi Giới tính
# 0        Lê Quang Trung   19       nam
# 1         Trần Công Huy   20       nam
# 2     Nguyễn Đình Thịnh   19       nam
# 3  Nguyễn Đắc Nhẫn Minh   19       nam
# 4  Đặng Thái Nhật Minh    20       nam
# 5           Lê Tuấn Anh   19       nam
# 6        Phạm Thị Lê Na   18        nữ
# 7          Lê Quang Hòa   46       nam
# 8          Hồ Thị Tuyết   39        nữ
# 9    Nguyễn Thanh Triều   21       nam

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
ho_va_ten = pd.Series(["Lê Quang Trung","Trần Công Huy","Nguyễn Đình Thịnh","Nguyễn Đắc Nhẫn Minh","Đặng Thái Nhật Minh ","Lê Tuấn Anh","Phạm Thị Lê Na","Lê Quang Hòa","Hồ Thị Tuyết","Nguyễn Thanh Triều"])
tuoi = pd.Series([19,20,19,19,20,19,18,46,39,21])
gioi_tinh = ["nam","nam","nam","nam","nam","nam","nữ","nam","nữ","nam"]
df2= pd.DataFrame({"Họ và tên": ho_va_ten,"Tuổi": tuoi,"Giới tính":gioi_tinh})
df2
# Out:
#               Họ và tên  Tuổi Giới tính
# 0        Lê Quang Trung    19       nam
# 1         Trần Công Huy    20       nam
# 2     Nguyễn Đình Thịnh    19       nam
# 3  Nguyễn Đắc Nhẫn Minh    19       nam
# 4  Đặng Thái Nhật Minh     20       nam
# 5           Lê Tuấn Anh    19       nam
# 6        Phạm Thị Lê Na    18        nữ
# 7          Lê Quang Hòa    46       nam
# 8          Hồ Thị Tuyết    39        nữ
# 9    Nguyễn Thanh Triều    21       nam

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df3 = pd.DataFrame([{"Họ và tên":"Lê Quang Trung","Tuổi":19,"Giới tính":"nam"},{"Họ và tên":"Trần Công Huy","Tuổi":20 ,"Giới tính":"nam"},{"Họ và tên":"Nguyễn Đắc Nhẫn Minh","Tuổi":19,"Giới tính":"nam"},{"Họ và tên":"Đặng Thái Nhật Minh","Tuổi":20,"Giới tính":"nam"},{"Họ và tên":"Lê Tuấn Anh","Tuổi":19,"Giới tính":"nam"},{"Họ và tên":"Phạm Thị Lê Na","Tuổi":18,"Giới tính":"nữ"},{"Họ và tên":"Lê Quang Hòa","Tuổi":46,"Giới tính":"nam"},{"Họ và tên":"Hồ Thị Tuyết","Tuổi":39,"Giới tính":"nữ "},{"Họ và tên":"Nguyễn Thanh Triều","Tuổi":21,"Giới tính":"nam"},{"Họ và tên":"Nguyễn Đình Thịnh","Tuổi":19 ,"Giới tính":"nam"}])
df3
# Out:
#               Họ và tên  Tuổi Giới tính
# 0        Lê Quang Trung    19       nam
# 1         Trần Công Huy    20       nam
# 2  Nguyễn Đắc Nhẫn Minh    19       nam
# 3   Đặng Thái Nhật Minh    20       nam
# 4           Lê Tuấn Anh    19       nam
# 5        Phạm Thị Lê Na    18        nữ
# 6          Lê Quang Hòa    46       nam
# 7          Hồ Thị Tuyết    39       nữ
# 8    Nguyễn Thanh Triều    21       nam
# 9     Nguyễn Đình Thịnh    19       nam

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
df4 = pd.DataFrame(zip(ho_va_ten, tuoi, gioi_tinh), columns = ["Họ và tên", "Tuổi", "Giới tính"])
df4
# Out:
#               Họ và tên  Tuổi Giới tính
# 0        Lê Quang Trung    19       nam
# 1         Trần Công Huy    20       nam
# 2     Nguyễn Đình Thịnh    19       nam
# 3  Nguyễn Đắc Nhẫn Minh    19       nam
# 4  Đặng Thái Nhật Minh     20       nam
# 5           Lê Tuấn Anh    19       nam
# 6        Phạm Thị Lê Na    18        nữ
# 7          Lê Quang Hòa    46       nam
# 8          Hồ Thị Tuyết    39        nữ
# 9    Nguyễn Thanh Triều    21       nam
