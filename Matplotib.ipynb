# %% [markdown]
# <a href="https://colab.research.google.com/github/rekuantsun/PTDL-Python/blob/main/Matplotib.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import matplotlib.pyplot as plt

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
x = np.linspace(-6,5,num=1500)

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
y = x**3+ 3*x +7
y1 = 3*(x**2) + 3
y2 = 6*x

# %% [markdown]
# ![image.png](data:image/png;base64,...)

# %%
fig, ax = plt.subplots()
ax.plot(x,y,label="y(x)",color = "blue")
ax.plot(x,y1,label="y'(x)",color = "red")
ax.plot(x,y2,label="y''(x)",color="green")
plt.xlabel("x");
plt.ylabel("y");
plt.title("Đồ thị hàm số ")
plt.legend();
